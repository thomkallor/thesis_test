# %%
import json as JSON

# %%
def load(path):
    with open('/root/'+path) as f:
        data=JSON.load(f)
        return data

# %%
train_acc=load('train_acc.json')
test_acc=load('test_acc.json')
train_loss=load('train_loss.json')
test_loss=load('test_loss.json')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.ndimage.filters import gaussian_filter1d
epochs=100

test_acc_smooth = gaussian_filter1d(test_acc, sigma=0.5)
train_loss_smooth = gaussian_filter1d(train_loss, sigma=0.5)
_, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(range(epochs), train_loss_smooth)
ax2.plot(range(len(test_acc_smooth)), test_acc_smooth, 'r')
ax1.set_xlabel('epoch')
ax1.set_ylabel('train loss')
ax2.set_ylabel('test accuracy')
ax2.set_title('Test Accuracy: {:.2f}'.format(test_acc[-1]))
# Out:
# Text(0.5,1,'Test Accuracy: 0.55')
